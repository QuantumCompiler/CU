# %%
pip install datascience
# Out:
# Requirement already satisfied: datascience in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (0.17.6)
# Requirement already satisfied: scipy in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (1.7.3)
# Requirement already satisfied: ipython in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (8.2.0)
# Requirement already satisfied: plotly in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (5.6.0)
# Requirement already satisfied: setuptools in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (61.2.0)
# Requirement already satisfied: numpy in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (1.21.5)
# Requirement already satisfied: pandas in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (3.5.1)
# Requirement already satisfied: folium>=0.9.1 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (0.14.0)
# Requirement already satisfied: branca in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from datascience) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from folium>=0.9.1->datascience) (2.11.3)
# Requirement already satisfied: requests in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from folium>=0.9.1->datascience) (2.27.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9->folium>=0.9.1->datascience) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->datascience) (3.0.4)
# Requirement already satisfied: six>=1.5 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->datascience) (1.16.0)
# Requirement already satisfied: backcall in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.7.5)
# Requirement already satisfied: appnope in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.1.2)
# Requirement already satisfied: matplotlib-inline in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.1.2)
# Requirement already satisfied: stack-data in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (3.0.20)
# Requirement already satisfied: decorator in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from ipython->datascience) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython->datascience) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython->datascience) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->datascience) (0.2.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from pandas->datascience) (2021.3)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from plotly->datascience) (8.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.9.1->datascience) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.9.1->datascience) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.9.1->datascience) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from requests->folium>=0.9.1->datascience) (1.26.9)
# Requirement already satisfied: executing in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->datascience) (0.8.3)
# Requirement already satisfied: asttokens in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->datascience) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/maribethoscamou/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython->datascience) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datascience import *
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plots
import collections
collections.Iterable = collections.abc.Iterable
plots.style.use('fivethirtyeight')

# %%
# Predefined functions; they should look familiar to functions you've coded in assignments!
def standard_units(arr):
    return (arr - np.average(arr))/np.std(arr)

def correlation(t, x, y):
    x_standard = standard_units(t.column(x))
    y_standard = standard_units(t.column(y))
    return np.average(x_standard * y_standard)

def slope(t, x, y):
    r = correlation(t, x, y)
    y_sd = np.std(t.column(y))
    x_sd = np.std(t.column(x))
    return r * y_sd / x_sd

def intercept(t, x, y):
    x_mean = np.mean(t.column(x))
    y_mean = np.mean(t.column(y))
    return y_mean - slope(t, x, y)*x_mean

def fitted_values(t, x, y):
    """Return an array of the regression estimates at all the x values"""
    a = slope(t, x, y)
    b = intercept(t, x, y)
    return a*t.column(x) + b

def residuals(t, x, y):
    """Return an array of all the residuals"""
    predictions = fitted_values(t, x, y)
    return t.column(y) - predictions

# %% [markdown]
# ## Regression Model (Demo)

# %%
# This code produces plots for demonstrating the regression model
def draw_and_compare(true_slope, true_intercept, sample_size):
    x=np.random.normal(50, 5, sample_size)
    xlims=np.array([np.min(x),np.max(x)])   
    errors=np.random.normal(0, 6, sample_size)
    y=(true_slope*x+ true_intercept)+errors
    sample=Table().with_columns('x',x,'y',y)
#     sample.scatter('x','y')
#     plots.plot(xlims, true_slope*xlims+ true_intercept, lw=2, color='green', label='True Line')
#     plots.title('True line and pointes created')
#     plots.legend()
    
#     sample.scatter('x','y')
#     plots.title('What we get to see')
    
    
#     sample.scatter('x','y', fit_line=True)
#     plots.title('Regression Estimate')
    
    sample.scatter('x','y', fit_line=True, label='Estimated Line')
    plots.plot(xlims, true_slope*xlims+ true_intercept, lw=2, color='green', label='True Line')
    plots.title('Regression line and True line')
    plots.legend()

# %%
draw_and_compare(2, -5, 100)

# %%
draw_and_compare(2, -5, 10)

# %%
draw_and_compare(2, -5, 100)

# %%
draw_and_compare(2, -5, 100)

# %% [markdown]
# <br><br><br>
#
# ---
#
# <center> Return to Slides </ceter>
#
# ---
#
# <br><br><br>

# %% [markdown]
# ## Prediction (Demo)

# %%
births = Table.read_table('baby.csv')
births.show(3)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Birth Weight</th> <th>Gestational Days</th> <th>Maternal Age</th> <th>Maternal Height</th> <th>Maternal Pregnancy Weight</th> <th>Maternal Smoker</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>120         </td> <td>284             </td> <td>27          </td> <td>62             </td> <td>100                      </td> <td>False          </td>
#         </tr>
#         <tr>
#             <td>113         </td> <td>282             </td> <td>33          </td> <td>64             </td> <td>135                      </td> <td>False          </td>
#         </tr>
#         <tr>
#             <td>128         </td> <td>279             </td> <td>28          </td> <td>64             </td> <td>115                      </td> <td>True           </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1171 rows omitted)</p>

# %%
# Preterm and postterm pregnancy cutoffs, according to the CDC
37 * 7, 42 * 7
# Out:
# (259, 294)

# %%
births.scatter('Gestational Days', 'Birth Weight')

# %%
births = births.where('Gestational Days', are.between(225, 325))

# %%
births.scatter('Gestational Days', 'Birth Weight')

# %% [markdown]
# ## Suppose we assume the regression model

# %%
correlation(births, 'Gestational Days', 'Birth Weight')
# Out:
# 0.42295118452423991

# %%
births.scatter('Gestational Days', 'Birth Weight', fit_line=True)

# %% [markdown]
# ## Prediction at a Given Value of x

# %%
def prediction_at(t, x, y, x_value):
    '''
    t - table
    x - label of x column
    y - label of y column
    x_value - the x value for which we want to predict y
    '''
    return slope(t, x, y) * x_value + intercept(t, x, y)

# %%
prediction_at_300 = prediction_at(births, 'Gestational Days', 'Birth Weight', 300)
prediction_at_300
# Out:
# 130.80951674248769

# %%
x = 300
births.scatter('Gestational Days', 'Birth Weight', fit_line=True)
plots.plot([x, x], [40, prediction_at_300], color='red', lw=2);

# %% [markdown]
# <br><br><br>
#
# ---
#
# <center> Return to Slides </ceter>
#
# ---
#
# <br><br><br>

# %% [markdown]
# ## Bootstrapping the Sample (Demo)

# %%
plots.figure(figsize=(10, 11))
plots.subplot(3, 2, 1)
plots.scatter(births[1], births[0], s=10, color='darkblue')
plots.xlim([225, 325])
plots.title('Original sample')

for i in np.arange(1, 6, 1):
    plots.subplot(3,2,i+1)
    resampled = births.sample()
    plots.scatter(resampled.column('Gestational Days'), resampled.column('Birth Weight'), s=10, color='tab:green')
    plots.xlim([225, 325])
    plots.title('Bootstrap sample '+str(i))
plots.tight_layout()

# %%
for i in np.arange(4):
    resample = births.sample()
    predicted_y = prediction_at(resample, 'Gestational Days', 'Birth Weight', 300)
    print('Predicted y from bootstrap sample was', predicted_y)
    resample.scatter('Gestational Days', 'Birth Weight', fit_line=True)
    plots.scatter(300, predicted_y, color='gold', s=50, zorder=3);
    plots.plot([x, x], [40, predicted_y], color='red', lw=2);
    plots.plot([200, x], [predicted_y, predicted_y], color='red', lw=2);
# Out:
# Predicted y from bootstrap sample was 130.172513138
# Predicted y from bootstrap sample was 129.250561376
# Predicted y from bootstrap sample was 130.885151268
# Predicted y from bootstrap sample was 129.807348624

# %% [markdown]
# # Predictions at 3 different points:

# %%
lines = Table(['slope','intercept', 'at 210', 'at 300', 'at 320'])

for i in range(10):
    resample = births.sample()
    a = slope(resample, 'Gestational Days', 'Birth Weight')
    b = intercept(resample, 'Gestational Days', 'Birth Weight')
    lines.append([a, b, a * 210 + b, a * 300 + b, a * 320 + b])
lines
# Out:
# slope    | intercept | at 210  | at 300  | at 320
# 0.481368 | -14.8555  | 86.2316 | 129.555 | 139.182
# 0.539941 | -31.506   | 81.8816 | 130.476 | 141.275
# 0.52142  | -26.649   | 82.8493 | 129.777 | 140.205
# 0.489911 | -17.131   | 85.7503 | 129.842 | 139.64
# 0.550566 | -34.0289  | 81.5899 | 131.141 | 142.152
# 0.557555 | -36.1508  | 80.9356 | 131.116 | 142.267
# 0.564948 | -39.3154  | 79.3237 | 130.169 | 141.468
# 0.525002 | -27.819   | 82.4314 | 129.682 | 140.182
# 0.609548 | -50.29    | 77.715  | 132.574 | 144.765
# 0.546517 | -32.9411  | 81.8276 | 131.014 | 141.944

# %%
for i in np.arange(lines.num_rows):
    line = lines.row(i)
    plots.plot([210, 320], [line.item('at 210'), line.item('at 320')], lw=1)
    plots.scatter(300, line.item('at 300'), s=30, zorder=3)

# %%
np.mean(births.column('Gestational Days')), np.mean(births.column('Birth Weight'))
# Out:
# (279.11015490533561, 119.57401032702238)

# %% [markdown]
# # Zooming at 300

# %%
lines = Table(['slope','intercept', 'at 291', 'at 300', 'at 309'])

for i in range(10):
    resample = births.sample()
    a = slope(resample, 'Gestational Days', 'Birth Weight')
    b = intercept(resample, 'Gestational Days', 'Birth Weight')
    lines.append([a, b, a * 291 + b, a * 300 + b, a * 309 + b])
lines
# Out:
# slope    | intercept | at 291  | at 300  | at 309
# 0.543534 | -32.195   | 125.973 | 130.865 | 135.757
# 0.474792 | -13.2665  | 124.898 | 129.171 | 133.444
# 0.506681 | -22.0033  | 125.441 | 130.001 | 134.561
# 0.536515 | -29.988   | 126.138 | 130.967 | 135.795
# 0.492306 | -17.1956  | 126.065 | 130.496 | 134.927
# 0.540657 | -30.1582  | 127.173 | 132.039 | 136.905
# 0.560191 | -36.9549  | 126.061 | 131.102 | 136.144
# 0.46886  | -10.5668  | 125.872 | 130.091 | 134.311
# 0.471864 | -12.2574  | 125.055 | 129.302 | 133.548
# 0.579021 | -41.7521  | 126.743 | 131.954 | 137.166

# %%
for i in np.arange(lines.num_rows):
     line = lines.row(i)
     plots.plot([291, 309], [line.item('at 291'), line.item('at 309')], lw=1)
     plots.scatter(300, line.item('at 300'), s=30, zorder=3)

# %% [markdown]
# ## Prediction Interval

# %%
np.int=np.int_
def bootstrap_prediction(t, x, y, new_x, repetitions=2500):
    """ 
    Makes a 95% confidence interval for the height of the true line at new_x, 
    using linear regression on the data in t (column names x and y).
    Shows a histogram of the bootstrap samples and shows the interval
    in gold.
    """

    # Bootstrap the scatter, predict, collect
    predictions = make_array()
    for i in np.arange(repetitions):
        resample = t.sample()
        predicted_y = prediction_at(resample, x, y, new_x)
        predictions = np.append(predictions, predicted_y)

    # Find the ends of the approximate 95% prediction interval
    left = percentile(2.5, predictions)
    right = percentile(97.5, predictions)
    round_left = round(left, 3)
    round_right = round(right, 3)

    # Display results
    Table().with_column('Prediction', predictions).hist(bins=20)
    plots.xlabel('predictions at x='+str(new_x))
    plots.plot([left, right], [0, 0], color='yellow', lw=8);
    print('Approximate 95%-confidence interval for height of true line at x =', new_x)
    print(round_left, 'to', round_right, '( width =', round(right - left, 3), ')')

# %%
bootstrap_prediction(births, 'Gestational Days', 'Birth Weight', 300)
# Out:
# Approximate 95%-confidence interval for height of true line at x = 300
# 128.898 to 132.687 ( width = 3.789 )

# %% [markdown]
# <br><br><br>
#
# ---
#
# <center> Return to Slides </ceter>
#
# ---
#
# <br><br><br>

# %% [markdown]
# ## Predictions at Different Values of x (Demo)

# %%
x = 300
births.scatter('Gestational Days', 'Birth Weight', fit_line=True)
plots.plot([x, x], [40, prediction_at_300], color='blue', lw=2);
prediction_at_230 = prediction_at(births, 'Gestational Days', 'Birth Weight', 230)
plots.plot([230, 230], [40, prediction_at_230], color='orange', lw=2);
prediction_at_280 = prediction_at(births, 'Gestational Days', 'Birth Weight', 280)
plots.plot([280, 280], [40, prediction_at_280], color='black', lw=2);

# %%
bootstrap_prediction(births, 'Gestational Days', 'Birth Weight', 230)
# Out:
# Approximate 95%-confidence interval for height of true line at x = 230
# 89.238 to 97.263 ( width = 8.025 )

# %%
bootstrap_prediction(births, 'Gestational Days', 'Birth Weight', 280)
# Out:
# Approximate 95%-confidence interval for height of true line at x = 280
# 119.086 to 120.959 ( width = 1.873 )

# %%
# No need to follow the code in this cell; just understand the graph

lines = Table(['slope','intercept', 'at 210', 'at 300', 'at 320'])

for i in range(10):
    resample = births.sample()
    a = slope(resample, 'Gestational Days', 'Birth Weight')
    b = intercept(resample, 'Gestational Days', 'Birth Weight')
    lines.append([a, b, a * 210 + b, a * 300 + b, a * 320 + b])

for i in np.arange(lines.num_rows):
    line = lines.row(i)
    plots.plot([210, 320], [line.item('at 210'), line.item('at 320')], lw=1)

# %% [markdown]
# <br><br><br>
#
# ---
#
# <center> Return to Slides </ceter>
#
# ---
#
# <br><br><br>

# %% [markdown]
# ## Inference for the True Slope (Demo)

# %%
births.scatter('Gestational Days', 'Birth Weight', fit_line=True)

# %%
slope(births, 'Gestational Days', 'Birth Weight')
# Out:
# 0.5378453676679036

# %%
def bootstrap_slope(t, x, y, repetitions=2500):
    """ 
    Makes a 95% confidence interval for the slope of the true line, 
    using linear regression on the data in t (column names x and y).
    Shows a histogram of the bootstrap samples and shows the interval
    in gold.
    """
    
    # Bootstrap the scatter, find the slope, collect
    slopes = make_array()
    for i in np.arange(repetitions):
        bootstrap_sample = t.sample()
        bootstrap_slope = slope(bootstrap_sample, x, y)
        slopes = np.append(slopes, bootstrap_slope)
    
    # Find the endpoints of the 95% confidence interval for the true slope
    left = percentile(2.5, slopes)
    right = percentile(97.5, slopes)
    round_left = round(left, 3)
    round_right = round(right, 3)
    
    # Slope of the regression line from the original sample
    observed_slope = slope(t, x, y)
    
    # Display results (no need to follow this code)
    Table().with_column('Bootstrap Slopes', slopes).hist(bins=20)
    plots.plot(make_array(left, right), make_array(0, 0), color='yellow', lw=8);
    print('Slope of regression line:', round(observed_slope, 3))
    print('Approximate 95%-confidence interval for the slope of the true line:')
    print(round_left, 'to', round_right)

# %%
bootstrap_slope(births, 'Gestational Days', 'Birth Weight')
# Out:
# Slope of regression line: 0.538
# Approximate 95%-confidence interval for the slope of the true line:
# 0.462 to 0.615

# %% [markdown]
# <br><br><br>
#
# ---
#
# <center> Return to Slides </ceter>
#
# ---
#
# <br><br><br>

# %% [markdown]
# ## Rain on the Regression Parade (Demo Slide 19)

# %%
draw_and_compare(0, 10, 15)

# %% [markdown]
# ### Maternal Age and Birth Weight

# %%
births.scatter('Maternal Age', 'Birth Weight')

# %%
slope(births, 'Maternal Age', 'Birth Weight')

# %%
births.scatter('Maternal Age', 'Birth Weight', fit_line=True)

# %% [markdown]
# <br><br><br>
#
# ### Hypothesis Test:
#
# **Null:** Slope of true line is equal to 0.
#
# **Alternative:** Slope of true line is not equal to 0.

# %%
bootstrap_slope(births, 'Maternal Age', 'Birth Weight')
